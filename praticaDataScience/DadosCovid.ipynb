# %%
import pandas as pd

# %%
url = "dataset/covid_19.csv"
pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[9], line 3
#       1 url = "dataset/covid_19.csv"
#       2 pd.read_csv(url)
# ----> 3 dados = pd.read_csv(url,sep=";")
#       4 dados
#
# ...

# %%
dados = pd.read_csv(url)
dados
# Out:
#               country      continent   population         day  \
# 0        Saint-Helena         Africa       6115.0  2024-06-30
# 1    Falkland-Islands  South-America       3539.0  2024-06-30
# 2          Montserrat  North-America       4965.0  2024-06-30
# 3    Diamond-Princess            NaN          NaN  2024-06-30
# 4        Vatican-City         Europe        799.0  2024-06-30
# ..                ...            ...          ...         ...
# 233         Argentina  South-America   46010234.0  2024-06-30
# 234       Netherlands         Europe   17211447.0  2024-06-30
# 235            Mexico  North-America  131562772.0  2024-06-30
# 236              Iran           Asia   86022837.0  2024-06-30
# 237         Indonesia           Asia  279134505.0  2024-06-30
#
#                           time     Cases  Recovered    Deaths        Tests
# 0    2024-06-30T16:15:16+00:00      2166        2.0       NaN          NaN
# ...

# %%
dados.head(10)
# Out:
#                  country      continent    population         day  \
# 0           Saint-Helena         Africa  6.115000e+03  2024-06-30
# 1       Falkland-Islands  South-America  3.539000e+03  2024-06-30
# 2             Montserrat  North-America  4.965000e+03  2024-06-30
# 3       Diamond-Princess            NaN           NaN  2024-06-30
# 4           Vatican-City         Europe  7.990000e+02  2024-06-30
# 5         Western-Sahara         Africa  6.261610e+05  2024-06-30
# 6             MS-Zaandam            NaN           NaN  2024-06-30
# 7                  China           Asia  1.448471e+09  2024-06-30
# 8                Tokelau        Oceania  1.378000e+03  2024-06-30
# 9  Saint-Pierre-Miquelon  North-America  5.759000e+03  2024-06-30
#
#                         time   Cases  Recovered  Deaths        Tests
# 0  2024-06-30T16:15:16+00:00    2166        2.0     NaN          NaN
# 1  2024-06-30T16:15:16+00:00    1930     1930.0     NaN       8632.0
# ...

# %%
dados.tail(10)
# Out:
#          country      continent   population         day  \
# 228       Russia         Europe  145805947.0  2024-06-30
# 229       Turkey           Asia   85561976.0  2024-06-30
# 230    Australia        Oceania   26068792.0  2024-06-30
# 231      Vietnam           Asia   98953541.0  2024-06-30
# 232       Taiwan           Asia   23888595.0  2024-06-30
# 233    Argentina  South-America   46010234.0  2024-06-30
# 234  Netherlands         Europe   17211447.0  2024-06-30
# 235       Mexico  North-America  131562772.0  2024-06-30
# 236         Iran           Asia   86022837.0  2024-06-30
# 237    Indonesia           Asia  279134505.0  2024-06-30
#
#                           time     Cases   Recovered    Deaths        Tests
# 228  2024-06-30T16:15:10+00:00  24124215  23545818.0  402756.0  273400000.0
# 229  2024-06-30T16:15:10+00:00  17232066         NaN  102174.0  162743369.0
# 230  2024-06-30T16:15:10+00:00  11853144  11820014.0   24414.0   81916639.0
# ...

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame
